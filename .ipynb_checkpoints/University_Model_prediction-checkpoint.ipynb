# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#Data Loading 
df=pd.read_csv("/Users/preethamhd/Downloads/Loan_data_dup.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Marital_status  Dependents     Education Employment  \
# 0  LP001002   Male             No         0.0      Graduate         No
# 1  LP001003   Male            Yes         1.0      Graduate         No
# 2  LP001005   Male            Yes         0.0      Graduate        Yes
# 3  LP001006   Male            Yes         0.0  Not Graduate         No
# 4  LP001008   Male             No         0.0      Graduate         No
#
#    Income  Co_applicant_income  LoanAmount   Term  Credit_History   Area  \
# 0    5849          1621.245798  146.165261  360.0             1.0  Urban
# 1    4583          1508.000000  128.000000  360.0             1.0  Rural
# 2    3000          1621.245798   66.000000  360.0             1.0  Urban
# 3    2583          2358.000000  120.000000  360.0             1.0  Urban
# 4    6000          1621.245798  141.000000  360.0             1.0  Urban
#
#   Loan_Status  Total_Icome  Income_log
# 0           Y       5849.0    8.674026
# 1           N       6091.0    8.430109
# 2           Y       3000.0    8.006368
# 3           Y       4941.0    7.856707
# 4           Y       6000.0    8.699515

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    float64
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         593 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 62.5+ KB

# %%
df['Total_Icome']=df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           21
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Total_Icome           0
# dtype: int64

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.rename(columns={'Self_Employed':'Employment'},inplace=True)
df.rename(columns={'ApplicantIncome':'Income'},inplace=True)
df.rename(columns={'CoapplicantIncome':'Co_applicant_income'},inplace=True)
df.rename(columns={'Property_Area':'Area'},inplace=True)
df.rename(columns={'Loan_Amount_Term':'Term'},inplace=True)
df.rename(columns={'Married':'Marital_status'},inplace=True)

# %%
df['Co_applicant_income'].value_counts()
# Out:
# 0.0       273
# 1666.0      5
# 2083.0      5
# 2500.0      5
# 1750.0      3
#          ...
# 7166.0      1
# 2138.0      1
# 2166.0      1
# 3541.0      1
# 3021.0      1
# Name: Co_applicant_income, Length: 287, dtype: int64

# %%
coapplicat_mean=df['Co_applicant_income'].mean()

# %%
df['Co_applicant_income']=df['Co_applicant_income'].replace([0.0],coapplicat_mean)

# %%
Loan_amount_mean=df['LoanAmount'].mean()

# %%
df['LoanAmount']=df['LoanAmount'].replace(0.0,Loan_amount_mean)

# %%
sns.countplot(df['Gender'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df['Marital_status'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(df['Employment'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Employment', ylabel='count'>

# %%
sns.countplot(df['Education'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(df['Area'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Area', ylabel='count'>

# %%
sns.countplot(df['Loan_Status'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.distplot(df['Income'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %%
df['Income_log']=np.log(df['Income'])

# %%
sns.distplot(df['Income_log'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income_log', ylabel='Density'>

# %%
sns.displot(df['Co_applicant_income'])

# %%
df['Co_applicant_income_log']=np.log(df['Co_applicant_income'])

# %%
sns.displot(df['Co_applicant_income_log'])

# %%
sns.distplot(df['Total_Icome'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total_Icome', ylabel='Density'>

# %%
df['Total_Icome_log']=np.log(df['Total_Icome'])

# %%
sns.distplot(df['Total_Icome_log'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total_Icome_log', ylabel='Density'>

# %%
sns.distplot(df['LoanAmount'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
df['Loan_amount_log']=np.log(df['LoanAmount'])

# %%
sns.displot(df['Loan_amount_log'])

# %%
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
sns.displot(df['Term'])

# %%
df['Term_log']=np.log(df['Term'])

# %%
sns.displot(df['Term_log'])

# %%
sns.displot(df['Credit_History'])

# %%
corr=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#     Loan_ID Gender Marital_status  Dependents     Education Employment  \
# 0  LP001002   Male             No         0.0      Graduate         No
# 1  LP001003   Male            Yes         1.0      Graduate         No
# 2  LP001005   Male            Yes         0.0      Graduate        Yes
# 3  LP001006   Male            Yes         0.0  Not Graduate         No
# 4  LP001008   Male             No         0.0      Graduate         No
#
#    Income  Co_applicant_income  LoanAmount   Term  Credit_History   Area  \
# 0    5849          1621.245798  146.165261  360.0             1.0  Urban
# 1    4583          1508.000000  128.000000  360.0             1.0  Rural
# 2    3000          1621.245798   66.000000  360.0             1.0  Urban
# 3    2583          2358.000000  120.000000  360.0             1.0  Urban
# 4    6000          1621.245798  141.000000  360.0             1.0  Urban
#
#   Loan_Status  Total_Icome  Income_log  Co_applicant_income_log  \
# 0           Y       5849.0    8.674026                 7.390950
# 1           N       6091.0    8.430109                 7.318540
# 2           Y       3000.0    8.006368                 7.390950
# 3           Y       4941.0    7.856707                 7.765569
# 4           Y       6000.0    8.699515                 7.390950
#
#    Total_Icome_log  Loan_amount_log  Term_log
# 0         8.674026         4.984738  5.886104
# 1         8.714568         4.852030  5.886104
# 2         8.006368         4.189655  5.886104
# 3         8.505323         4.787492  5.886104
# 4         8.699515         4.948760  5.886104

# %%
#cols=['Loan_ID','Income','Co_applicant_income','LoanAmount','Term','Co_applicant_income_log']

df=df.drop(columns=cols, axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-204-aba0c24b54ab> in <module>
#       1 #cols=['Loan_ID','Income','Co_applicant_income','LoanAmount','Term','Co_applicant_income_log']
#       2 col=["Total_Icome"]
# ----> 3 df=df.drop(columns=cols, axis=1)
#       4 df.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Loan_ID' 'Income' 'Co_applicant_income' 'LoanAmount' 'Term'\n 'Co_applicant_income_log'] not found in axis"

# %%
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   Gender Marital_status  Dependents     Education Employment  Credit_History  \
# 0   Male             No         0.0      Graduate         No             1.0
# 1   Male            Yes         1.0      Graduate         No             1.0
# 2   Male            Yes         0.0      Graduate        Yes             1.0
# 3   Male            Yes         0.0  Not Graduate         No             1.0
# 4   Male             No         0.0      Graduate         No             1.0
#
#     Area Loan_Status  Income_log  Total_Icome_log  Loan_amount_log  Term_log
# 0  Urban           Y    8.674026         8.674026         4.984738  5.886104
# 1  Rural           N    8.430109         8.714568         4.852030  5.886104
# 2  Urban           Y    8.006368         8.006368         4.189655  5.886104
# 3  Urban           Y    7.856707         8.505323         4.787492  5.886104
# 4  Urban           Y    8.699515         8.699515         4.948760  5.886104

# %%
del df['Total_Icome']

# %%
from sklearn.preprocessing import LabelEncoder
cols=['Gender','Marital_status','Education','Employment','Area','Loan_Status']
le=LabelEncoder()
for col in cols:
    df[col]=le.fit_transform(df[col])

# %%
df.head(10)
# Out:
#    Gender  Marital_status  Dependents  Education  Employment  Credit_History  \
# 0       1               0         0.0          0           0             1.0
# 1       1               1         1.0          0           0             1.0
# 2       1               1         0.0          0           1             1.0
# 3       1               1         0.0          1           0             1.0
# 4       1               0         0.0          0           0             1.0
# 5       1               1         2.0          0           1             1.0
# 6       1               1         0.0          1           0             1.0
# 7       1               1         3.0          0           0             0.0
# 8       1               1         2.0          0           0             1.0
# 9       1               1         1.0          0           0             1.0
#
#    Area  Loan_Status  Income_log  Total_Icome_log  Loan_amount_log  Term_log
# 0     2            1    8.674026         8.674026         4.984738  5.886104
# 1     0            0    8.430109         8.714568         4.852030  5.886104
# 2     2            1    8.006368         8.006368         4.189655  5.886104
# 3     2            1    7.856707         8.505323         4.787492  5.886104
# 4     2            1    8.699515         8.699515         4.948760  5.886104
# 5     2            1    8.597297         9.170872         5.587249  5.886104
# 6     2            1    7.754910         8.255569         4.553877  5.886104
# 7     1            0    8.018296         8.619750         5.062595  5.886104
# 8     2            1    8.295549         8.618305         5.123964  5.886104
# 9     1            0    9.460398        10.077819         5.855072  5.886104

# %%
x=df[['Gender','Marital_status','Dependents','Education','Employment','Credit_History','Area','Income_log','Total_Icome_log','Loan_amount_log','Term_log']]
y=df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.model_selection import  cross_val_score
def classify(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
    model.fit(x_train,y_train)
    print("accuracy is",model.score(x_test,y_test)*100)
    score=cross_val_score(model,x,y,cv=5)
    print("cross validation score is",np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
classify(model,x,y)
model.predict([[1,1,1.0,0,0,1.0,1,9.460398,10.077819,5.855072,5.886104]])
# Out:
# accuracy is 79.22077922077922
# cross validation score is 80.9462881514061
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([1])

# %%
x_train
# Out:
#      Gender  Marital_status  Dependents  Education  Employment  \
# 113       0               0         1.0          0           1
# 245       1               0         0.0          0           1
# 553       1               1         0.0          1           0
# 117       1               1         1.0          0           0
# 537       1               0         2.0          0           0
# ..      ...             ...         ...        ...         ...
# 525       1               1         2.0          0           1
# 95        1               0         0.0          0           0
# 365       1               0         0.0          1           0
# 294       1               1         0.0          0           0
# 356       1               1         2.0          0           0
#
#      Credit_History  Area  Income_log  Total_Icome_log  Loan_amount_log  \
# 113        1.000000     1    8.916104         8.916104         4.984738
# 245        1.000000     2    8.707814         9.247925         4.787492
# 553        0.000000     2    7.805475         8.473659         5.198497
# 117        0.842199     2    7.702556         8.192017         4.442651
# 537        1.000000     1    8.193400         8.193400         4.672829
# ..              ...   ...         ...              ...              ...
# 525        1.000000     0    9.769956         9.769956         5.991465
# 95         0.842199     2    8.822027         8.822027         4.984738
# 365        1.000000     0    8.734882         8.734882         4.890349
# 294        1.000000     1    7.776115         8.651199         5.147494
# 356        1.000000     0    9.027979         9.350102         5.105945
#
#      Term_log
# 113  5.886104
# 245  5.192957
# 553  5.886104
# 117  5.886104
# 537  5.886104
# ..        ...
# 525  5.886104
# 95   5.886104
# 365  5.886104
# 294  5.886104
# 356  5.886104
#
# [460 rows x 11 columns]
